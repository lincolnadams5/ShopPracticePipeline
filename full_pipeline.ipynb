# %% [markdown]
# # Full Machine Learning Pipeline
#
# ## Job 1: ETL to Build the Warehouse
# ---

# %%
import sqlite3
import pandas as pd

# Connect to operational database
conn = sqlite3.connect("shop.db")

# Load core tables
orders = pd.read_sql("SELECT * FROM orders", conn)
customers = pd.read_sql("SELECT * FROM customers", conn)
order_items = pd.read_sql("SELECT * FROM order_items", conn)
products = pd.read_sql("SELECT * FROM products", conn)
product_reviews = pd.read_sql("SELECT * FROM product_reviews", conn)
shipments = pd.read_sql("SELECT * FROM shipments", conn)

conn.close()

print(orders.shape, customers.shape, order_items.shape, products.shape)
# Out:
# (5000, 17) (250, 12) (15022, 6) (100, 7)

# %%
src = sqlite3.connect('shop.db')

orders      = pd.read_sql('SELECT * FROM orders', src)
customers   = pd.read_sql('SELECT * FROM customers', src)
shipments   = pd.read_sql('SELECT * FROM shipments', src)
order_items = pd.read_sql('''
    SELECT oi.order_id,
           oi.quantity, oi.unit_price, oi.line_total,
           p.category
    FROM order_items oi
    JOIN products p ON oi.product_id = p.product_id
''', src)
reviews = pd.read_sql('SELECT customer_id, rating FROM product_reviews', src)

src.close()

# %%
# Aggregate order items
warehouse = (
order_items
    .merge(products, on="product_id", how="left")
    .groupby("order_id")
    .agg(
    num_items=("quantity", "sum"),
    avg_price=("price", "mean"),
    total_value=("price", "sum"),
    avg_weight=("weight", "mean")
    )
    .reset_index()
)

order_item_features.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 6
#       1 # Aggregate order items
#       2 order_item_features = (
#       3 order_items
#       4     .merge(products, on="product_id", how="left")
#       5     .groupby("order_id")
# ----> 6     .agg(
#       7     num_items=("quantity", "sum"),
#       8     avg_price=("price", "mean"),
#       9     total_value=("price", "sum"),
#      10     avg_weight=("weight", "mean")
#      11     )
#      12     .reset_index()
#      13 )
#      15 order_item_features.head()
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\apply.py:550, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     548 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     549 func = cast(AggFuncTypeDict, self.func)
# --> 550 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     552 is_non_unique_col = (
#     553     selected_obj.ndim == 2
#     554     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     555 )
#     557 if selected_obj.ndim == 1:
#     558     # key only used for output
#
# File c:\Users\apier\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\apply.py:762, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     759     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     760     if len(cols) > 0:
#     761         # GH 58474
# --> 762         raise KeyError(f"Label(s) {list(cols)} do not exist")
#     764 aggregator_types = (list, tuple, dict)
#     766 # if we have a dict of any non-scalars
#     767 # eg. {'A' : ['mean']}, normalize all to
#     768 # be list-likes
#     769 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Label(s) ['weight'] do not exist"

# %% [markdown]
# ## Job 2: Train the Model and Save the Artifacts
# ---

# %% [markdown]
# ## Job 3: Run Inference and Write Predictions to `shop.db`
# ---
